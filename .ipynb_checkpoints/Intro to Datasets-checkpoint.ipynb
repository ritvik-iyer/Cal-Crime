# %% [markdown]
# # Getting the Data

# %% [markdown]
# ### Dependencies; uncomment the lines below if you haven't installed these packages

# %%
pip install sodapy
# Out:
#   File "<ipython-input-5-e69c07ae6d1e>", line 1
#     pip install sodapy
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd 
from sodapy import Socrata
client = Socrata("data.cityofberkeley.info",
                  'hDgMK5whfNUoA9aRqeM71eNkM',            #refer to SLACK 
                  username="rikiiyer@berkeley.edu",        #refer to SLACK 
                  password="CalCrime1121")       #refer to SLACK 
#arrests = pd.DataFrame.from_records(client.get('xi7q-nji6'))
#inquiries = pd.DataFrame.from_records(client.get('bscu-qpbu'))
calls = pd.DataFrame.from_records(client.get('k2nh-s5h5'))
stops = pd.DataFrame.from_records(client.get('6e9j-pj9p'))
#jail = pd.DataFrame.from_records(client.get('7ykt-c32j'))

# %% [markdown]
# ## Arrests Dataset

# %%
arrests.head() #not very useful
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-726c26ae2302> in <module>()
# ----> 1 arrests.head() #not very useful
#
# NameError: name 'arrests' is not defined

# %% [markdown]
# ### The arrests dataset contains no information on where the person was arrested; this makes it very difficult for us to use in a mapping software.

# %%
inquiries.head() #not very useful
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2b42475328fe> in <module>()
# ----> 1 inquiries.head() #not very useful
#
# NameError: name 'inquiries' is not defined

# %%
calls.head()
# Out:
#   :@computed_region_3ini_iehf :@computed_region_5bih_7r3y  \
# 0                           9                          11
# 1                          11                          32
# 2                           6                          28
# 3                           1                          17
# 4                           6                          11
#
#   :@computed_region_5s6d_2f32 :@computed_region_b3wi_w8ix  \
# 0                        1502                           7
# 1                        1496                           1
# 2                        1494                           8
# 3                        1500                           6
# 4                        1502                           8
#
#   :@computed_region_fhmw_rucx :@computed_region_u3y2_d2ws  \
# 0                        1444                           7
# 1                         357                           1
# 2                         704                           8
# 3                        1055                           6
# 4                        1441                           8
#
#   :@computed_region_x3q3_gi3e                   blkaddr  \
# 0                           5  HARRISON STREET & 5TH ST
# 1                           1         2000 KITTREDGE ST
# 2                           8         2000 SAN PABLO AV
# 3                           4          1100 HILLVIEW RD
# 4                           8         200 UNIVERSITY AV
#
#                                       block_location    caseno      city  \
# 0  {u'latitude': u'37.880922', u'human_address': ...  19090820  Berkeley
# 1  {u'latitude': u'37.868204', u'human_address': ...  19019255  Berkeley
# 2  {u'latitude': u'37.868815', u'human_address': ...  19019086  Berkeley
# 3  {u'latitude': u'37.892987', u'human_address': ...  19090839  Berkeley
# 4  {u'latitude': u'37.865511', u'human_address': ...  19090886  Berkeley
#
#   cvdow               cvlegend                  eventdt eventtm  \
# 0     3     BURGLARY - VEHICLE  2019-04-10T00:00:00.000   20:30
# 1     3     BURGLARY - VEHICLE  2019-04-10T00:00:00.000   17:45
# 2     3  BURGLARY - COMMERCIAL  2019-04-10T00:00:00.000   04:39
# 3     3                  FRAUD  2019-04-10T00:00:00.000   00:00
# 4     3                LARCENY  2019-04-10T00:00:00.000   08:45
#
#                   indbdate                   offense state
# 0  2019-10-08T07:00:06.000             BURGLARY AUTO    CA
# 1  2019-10-08T07:00:06.000             BURGLARY AUTO    CA
# 2  2019-10-08T07:00:06.000       BURGLARY COMMERCIAL    CA
# 3  2019-10-08T07:00:06.000            IDENTITY THEFT    CA
# 4  2019-10-08T07:00:06.000  THEFT MISD. (UNDER $950)    CA

# %%
calls.columns
# Out:
# Index([':@computed_region_3ini_iehf', ':@computed_region_5bih_7r3y',
#        ':@computed_region_5s6d_2f32', ':@computed_region_b3wi_w8ix',
#        ':@computed_region_fhmw_rucx', ':@computed_region_u3y2_d2ws',
#        ':@computed_region_x3q3_gi3e', 'blkaddr', 'block_location', 'caseno',
#        'city', 'cvdow', 'cvlegend', 'eventdt', 'eventtm', 'indbdate',
#        'offense', 'state'],
#       dtype='object')

# %%
stops.columns
# Out:
# Index([':@computed_region_5s6d_2f32', 'call_date_time', 'dispositions',
#        'incident_number', 'incident_type', 'location', 'location_1_address',
#        'location_1_city', 'location_1_state'],
#       dtype='object')

# %%
stops.head()
# Out:
#   :@computed_region_5s6d_2f32           call_date_time dispositions  \
# 0                         NaN  2015-01-26T00:10:00.000            M
# 1                         NaN  2015-01-26T00:50:00.000            M
# 2                         NaN  2015-01-26T01:03:00.000            M
# 3                         NaN  2015-01-26T07:16:00.000       BM4ICN
# 4                         NaN  2015-01-26T07:43:00.000       BM4ICN
#
#   incident_number incident_type                      location  \
# 0   2015-00004825             T     SAN PABLO AVE / MARIN AVE
# 1   2015-00004829             T  SAN PABLO AVE / CHANNING WAY
# 2   2015-00004831             T     UNIVERSITY AVE / NINTH ST
# 3   2015-00004848          1194       2000 BLOCK BERKELEY WAY
# 4   2015-00004849          1194      1700 BLOCK SAN PABLO AVE
#
#              location_1_address location_1_city location_1_state
# 0     SAN PABLO AVE / MARIN AVE          Albany               CA
# 1  SAN PABLO AVE / CHANNING WAY        Berkeley               CA
# 2     UNIVERSITY AVE / NINTH ST        Berkeley               CA
# 3       2000 BLOCK BERKELEY WAY        Berkeley               CA
# 4      1700 BLOCK SAN PABLO AVE        Berkeley               CA

# %%
jail.head() #not very useful
# Out:
#   age     arrest_date_and_time booking_agency    booking_date_and_time  \
# 0  41  2019-10-02T22:59:00.000      CA0010300  2019-10-02T23:39:59.000
# 1  57  2019-10-02T21:40:00.000      CA0019700  2019-10-02T22:02:03.000
# 2  46  2019-10-02T17:16:00.000      CA0010300  2019-10-02T18:46:22.000
# 3  28  2019-10-02T16:22:00.000      CA0010300  2019-10-02T16:46:41.000
# 4  61  2019-10-02T10:32:00.000      CA0010300  2019-10-02T11:22:21.000
#
#   booking_number    case_number            date_of_birth      disposition  \
# 0  2019-00002650  2019-00055891  1978-09-06T00:00:00.000  SANTA RITA JAIL
# 1  2019-00002649  2019-00002762  1961-11-07T00:00:00.000  SANTA RITA JAIL
# 2  2019-00002648  2019-00055837  1973-06-27T00:00:00.000              NaN
# 3  2019-00002647  2019-00055811  1991-09-23T00:00:00.000        CITE-JAIL
# 4  2019-00002646  2019-00055759  1958-04-20T00:00:00.000        CITE-JAIL
#
#   eyes hair        height  occupation   race   sex  \
# 0  BRO  BLD   6 Ft. 4 In.         NaN  Black  Male
# 1  BLU  BLN  5 Ft. 11 In.  UNEMPLOYED  White  Male
# 2  BLU  BLN   6 Ft. 0 In.         NaN  White  Male
# 3  BLK  BRO   6 Ft. 1 In.         NaN  Black  Male
# 4  BRO  GRY   6 Ft. 2 In.         NaN  White  Male
#
#                                   statute  \
# 0  11364 (A); 11377 (A); 466; 1203.2 - M;
# 1                                   3056;
# 2                                    459;
# 3                   11377 (A); 11364 (A);
# 4                                602 (M);
#
#                                  statute_description statute_type  \
# 0  Possess narcotics paraphernalia; Possession of...      HS; PC;
# 1                               Violation of Parole;          PC;
# 2                                          Burglary;          PC;
# 3  Possession of controlled substances; Possess n...          HS;
# 4          TRESPASS:OCCUPY PROPERTY WITHOUT CONSENT;          PC;
#
#                     subject weight
# 0          Janae Aaron Bell    240
# 1    STEVEN MICHAEL DOUGLAS    170
# 2  Christopher Andrew Lerch    275
# 3   Curtis Roshawn Phillips    260
# 4     RANDALL MERLE SIMPSON    175

# %% [markdown]
# ### The jail dataset contains no information on where the person was arrested; this makes it very difficult for us to use in a mapping software

# %% [markdown]
# # The datasets which we can actually use are: calls, stops
